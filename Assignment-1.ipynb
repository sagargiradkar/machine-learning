# %% [markdown]
# ### 1. Assignment No1
# ### Perform following operation on given dataset.
# ### a) Load the Data set
# ### b) Find Shape of Data
# ### c) Find the summary of the data
# ### d) Find data type of each column
# ### e) Find Missing Values
# ### f) Finding out Zero's
# ### g) Find Mean
# ### h) Replace the missing values
# ### i) Draw the pair plot
# ### j) Create subsets as per give instructions
# ### k) divide dataset in training (75%) and testing (25%).

# %%
import pandas as pd

# %%
ls
# Out:
# air_data.csv  Assignment-1.ipynb  Assignment-2.ipynb  Heart.csv

# %% [markdown]
# ### a) Load the Data set

# %%
import pandas as pd

heart_data = pd.read_csv('Heart.csv')

# %%
heart_data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
heart_data = heart_data.drop("Unnamed: 0",axis=1)

# %% [markdown]
# ### Display first five

# %%
heart_data.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %% [markdown]
# ### b) Find Shape of Data

# %%
shape = heart_data.shape
print("Shape of Data:", shape)
# Out:
# Shape of Data: (303, 14)

# %% [markdown]
# ### c) Find the summary of the data

# %%
summary = heart_data.describe()
print("Summary of Data:\n", summary)
# Out:
# Summary of Data:
#                Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
 heart_data.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %% [markdown]
# ### d) Find data type of each column

# %%
data_types = heart_data.dtypes
print("Data Types of Columns:\n", data_types)
# Out:
# Data Types of Columns:
#  Age            int64
# Sex            int64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %% [markdown]
# ### Null values

# %%
heart_data.isnull()
# Out:
#        Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  ExAng  \
# 0    False  False      False   False  False  False    False  False  False
# 1    False  False      False   False  False  False    False  False  False
# 2    False  False      False   False  False  False    False  False  False
# 3    False  False      False   False  False  False    False  False  False
# 4    False  False      False   False  False  False    False  False  False
# ..     ...    ...        ...     ...    ...    ...      ...    ...    ...
# 298  False  False      False   False  False  False    False  False  False
# 299  False  False      False   False  False  False    False  False  False
# 300  False  False      False   False  False  False    False  False  False
# 301  False  False      False   False  False  False    False  False  False
# 302  False  False      False   False  False  False    False  False  False
#
#      Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
heart_data.isna().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %% [markdown]
# ### e) Find Missing Values

# %%
missing_values = heart_data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %% [markdown]
# ### Replace Null values

# %%
heart_data["Ca"].fillna(heart_data["Ca"].mean(),inplace=True)

# %%
heart_data
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope        Ca        Thal  AHD
# 0        2.3      3  0.000000       fixed   No
# ...

# %%
missing_values = heart_data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         2
# AHD          0
# dtype: int64

# %%
#missing_values = heart_data.fillna(mean_values, inplace=True)

# %%
heart_data["Thal"].fillna(heart_data["Thal"] == 'reversable',inplace=True)

# %%
heart_data
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope        Ca        Thal  AHD
# 0        2.3      3  0.000000       fixed   No
# ...

# %%
missing_values = heart_data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
#heart_data.dropna()

# %% [markdown]
# ### f) Finding out Zero's

# %%
heart_data == 0
# Out:
#        Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  ExAng  \
# 0    False  False      False   False  False  False    False  False   True
# 1    False  False      False   False  False   True    False  False  False
# 2    False  False      False   False  False   True    False  False  False
# 3    False  False      False   False  False   True     True  False   True
# 4    False   True      False   False  False   True    False  False   True
# ..     ...    ...        ...     ...    ...    ...      ...    ...    ...
# 298  False  False      False   False  False   True     True  False   True
# 299  False  False      False   False  False  False     True  False   True
# 300  False  False      False   False  False   True     True  False  False
# 301  False   True      False   False  False   True    False  False   True
# 302  False  False      False   False  False   True     True  False   True
#
#      Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
zeros = (heart_data == 0).sum()
print("Zeros in Columns:\n", zeros)
# Out:
# Zeros in Columns:
#  Age            0
# Sex           97
# ChestPain      0
# RestBP         0
# Chol           0
# Fbs          258
# RestECG      151
# MaxHR          0
# ExAng        204
# Oldpeak       99
# Slope          0
# Ca           176
# Thal           2
# AHD            0
# dtype: int64

# %% [markdown]
# ### g) Find Mean of each coloum

# %%
heart_data[["Age","RestBP","Fbs","RestECG","MaxHR","ExAng","Oldpeak","Slope","Ca"]].mean()
# Out:
# Age         54.438944
# RestBP     131.689769
# Fbs          0.148515
# RestECG      0.990099
# MaxHR      149.607261
# ExAng        0.326733
# Oldpeak      1.039604
# Slope        1.600660
# Ca           0.672241
# dtype: float64

# %% [markdown]
# ### h) Replace the missing values

# %%
# mean_values = heart_data.mean()
# print("Mean of Columns:\n", mean_values)

# %%
# missing_values = heart_data.fillna(mean_values, inplace=True)

# %% [markdown]
# ### i) Draw the pair plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(heart_data ,hue = 'ChestPain')
plt.show()

# %%
# sns.pairplot(heart_data, hue="ChestPain")

# %% [markdown]
# ### j) Create subsets as per give instructions

# %% [markdown]
# #### Age > 55 and ChestPain ==nontypical

# %%
subset = heart_data[(heart_data['Age'] > 55) & (heart_data['ChestPain'] =='nontypical')]

# %%
subset
# Out:
#      Age  Sex   ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 5     56    1  nontypical     120   236    0        0    178      0      0.8
# 11    56    0  nontypical     140   294    0        2    153      0      1.3
# 22    58    1  nontypical     120   284    0        2    160      0      1.8
# 42    71    0  nontypical     160   302    0        0    162      0      0.4
# 137   62    1  nontypical     120   281    0        2    103      0      1.4
# 140   59    1  nontypical     140   221    0        0    164      1      0.0
# 185   63    0  nontypical     140   195    0        0    179      0      0.0
# 187   66    1  nontypical     160   246    0        0    120      1      0.0
# 233   74    0  nontypical     120   269    0        2    121      1      0.2
# 249   62    1  nontypical     128   208    1        2    140      0      0.0
# 258   70    1  nontypical     156   245    0        2    143      0      0.0
# ...

# %% [markdown]
# ### k) divide dataset in training (75%) and testing (25%)

# %%
x1 =heart_data.iloc[:,0:-1]

# %%
x1 = heart_data[["Age","Sex","ChestPain","RestBP","Fbs","RestECG","MaxHR","ExAng","Oldpeak","Slope","Ca","Thal"]]

# %%
x1
# Out:
#      Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1       typical     145    1        2    150      0      2.3
# 1     67    1  asymptomatic     160    0        2    108      1      1.5
# 2     67    1  asymptomatic     120    0        2    129      1      2.6
# 3     37    1    nonanginal     130    0        0    187      0      3.5
# 4     41    0    nontypical     130    0        2    172      0      1.4
# ..   ...  ...           ...     ...  ...      ...    ...    ...      ...
# 298   45    1       typical     110    0        0    132      0      1.2
# 299   68    1  asymptomatic     144    1        0    141      0      3.4
# 300   57    1  asymptomatic     130    0        0    115      1      1.2
# 301   57    0    nontypical     130    0        2    174      0      0.0
# 302   38    1    nonanginal     138    0        0    173      0      0.0
#
#      Slope        Ca        Thal
# 0        3  0.000000       fixed
# ...

# %%
x1
# Out:
#      Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1       typical     145    1        2    150      0      2.3
# 1     67    1  asymptomatic     160    0        2    108      1      1.5
# 2     67    1  asymptomatic     120    0        2    129      1      2.6
# 3     37    1    nonanginal     130    0        0    187      0      3.5
# 4     41    0    nontypical     130    0        2    172      0      1.4
# ..   ...  ...           ...     ...  ...      ...    ...    ...      ...
# 298   45    1       typical     110    0        0    132      0      1.2
# 299   68    1  asymptomatic     144    1        0    141      0      3.4
# 300   57    1  asymptomatic     130    0        0    115      1      1.2
# 301   57    0    nontypical     130    0        2    174      0      0.0
# 302   38    1    nonanginal     138    0        0    173      0      0.0
#
#      Slope        Ca        Thal
# 0        3  0.000000       fixed
# ...

# %%
y1 = heart_data.iloc[:,-1]

# %%
y1 = heart_data[["AHD"]]

# %%
y1
# Out:
#      AHD
# 0     No
# 1    Yes
# 2    Yes
# 3     No
# 4     No
# ..   ...
# 298  Yes
# 299  Yes
# 300  Yes
# 301  Yes
# 302   No
#
# [303 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1,train_size=0.75 ,test_size=0.25)

# %%
x1_train
# Out:
#      Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 38    55    1  asymptomatic     132    0        0    132      1      1.2
# 163   58    0  asymptomatic     100    0        2    122      0      1.0
# 82    39    1    nonanginal     140    0        2    182      0      0.0
# 25    50    0    nonanginal     120    0        0    158      0      1.6
# 128   44    1    nontypical     120    0        0    170      0      0.0
# ..   ...  ...           ...     ...  ...      ...    ...    ...      ...
# 196   69    1       typical     160    1        2    131      0      0.1
# 156   51    1  asymptomatic     140    0        0    173      1      1.6
# 72    62    1  asymptomatic     120    0        0     99      1      1.8
# 259   57    1    nontypical     124    0        0    141      0      0.3
# 207   50    1  asymptomatic     144    0        2    126      1      0.9
#
#      Slope   Ca        Thal
# 38       2  1.0  reversable
# 163      2  0.0      normal
# ...

# %%
x1_test
# Out:
#      Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 40    65    0  asymptomatic     150    0        2    114      0      1.0
# 17    54    1  asymptomatic     140    0        0    160      0      1.2
# 109   39    1  asymptomatic     118    0        0    140      0      1.2
# 56    50    1    nonanginal     140    0        0    163      0      0.6
# 63    54    0    nonanginal     135    1        0    170      0      0.0
# ..   ...  ...           ...     ...  ...      ...    ...    ...      ...
# 195   67    1  asymptomatic     100    0        2    125      1      0.9
# 49    53    1    nonanginal     130    1        2    152      0      1.2
# 12    56    1    nonanginal     130    1        2    142      1      0.6
# 252   64    1  asymptomatic     128    0        0    105      1      0.2
# 70    65    0    nonanginal     155    0        0    148      0      0.8
#
#      Slope   Ca        Thal
# 40       2  3.0  reversable
# 17       1  0.0      normal
# ...

# %%
y1_train
# Out:
#      AHD
# 38   Yes
# 163   No
# 82    No
# 25    No
# 128   No
# ..   ...
# 196   No
# 156  Yes
# 72   Yes
# 259  Yes
# 207  Yes
#
# [227 rows x 1 columns]

# %%
y1_test
# Out:
#      AHD
# 40   Yes
# 17    No
# 109  Yes
# 56   Yes
# 63    No
# ..   ...
# 195  Yes
# 49    No
# 12   Yes
# 252   No
# 70    No
#
# [76 rows x 1 columns]
